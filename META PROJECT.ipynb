# %%
import pandas as pd

# %%
meta = pd.read_excel(r"C:\Users\Gamini\Desktop\data\META.xlsx")#read the exel sheet

# %%
meta # dispaly the data base
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2023-05-30  265.250000  268.649994  261.290009  262.519989  262.241760
# 1   2023-05-31  260.000000  265.000000  258.450012  264.720001  264.439423
# 2   2023-06-01  265.899994  274.000000  265.890015  272.609985  272.321045
# 3   2023-06-02  272.660004  275.350006  271.119995  272.609985  272.321045
# 4   2023-06-05  270.299988  275.570007  269.559998  271.390015  271.102356
# ..         ...         ...         ...         ...         ...         ...
# 247 2024-05-22  467.869995  473.720001  465.649994  467.779999  467.779999
# 248 2024-05-23  472.880005  474.359985  461.540009  465.779999  465.779999
# 249 2024-05-24  467.619995  479.850006  466.299988  478.220001  478.220001
# 250 2024-05-28  476.579987  480.859985  474.839996  479.920013  479.920013
# 251 2024-05-29  474.660004  479.850006  473.700012  474.359985  474.359985
#
#        Volume
# 0    23816500
# 1    25473700
# 2    25609500
# ...

# %%
meta.head() #dispaly the 1st five rows of the data base
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-05-30  265.250000  268.649994  261.290009  262.519989  262.241760
# 1 2023-05-31  260.000000  265.000000  258.450012  264.720001  264.439423
# 2 2023-06-01  265.899994  274.000000  265.890015  272.609985  272.321045
# 3 2023-06-02  272.660004  275.350006  271.119995  272.609985  272.321045
# 4 2023-06-05  270.299988  275.570007  269.559998  271.390015  271.102356
#
#      Volume
# 0  23816500
# 1  25473700
# 2  25609500
# 3  19405300
# 4  20742900

# %%
meta.tail()# dispaly last five rows of data base
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 247 2024-05-22  467.869995  473.720001  465.649994  467.779999  467.779999
# 248 2024-05-23  472.880005  474.359985  461.540009  465.779999  465.779999
# 249 2024-05-24  467.619995  479.850006  466.299988  478.220001  478.220001
# 250 2024-05-28  476.579987  480.859985  474.839996  479.920013  479.920013
# 251 2024-05-29  474.660004  479.850006  473.700012  474.359985  474.359985
#
#        Volume
# 247  10078600
# 248  11747900
# 249  12012300
# 250  10175800
# 251   9208600

# %%
print(type(meta)) #describe the data type of the databse
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
meta.describe()# give the summary of the statistics of the each coloumn
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   369.568096  374.519603  365.027301  369.967619  369.716447
# std     83.162349   83.954313   82.059705   83.028267   83.139238
# min    260.000000  265.000000  258.450012  262.519989  262.241760
# 25%    301.739998  306.659988  298.817497  301.547508  301.227906
# 50%    329.830002  334.524994  326.040008  332.729995  332.377335
# 75%    467.682495  472.899994  462.414993  468.389991  468.280746
# max    529.280029  531.489990  518.890015  527.340027  527.340027
#
#              Volume
# count  2.520000e+02
# mean   1.961415e+07
# std    1.021427e+07
# min    5.467500e+06
# 25%    1.391308e+07
# 50%    1.755555e+07
# 75%    2.153340e+07
# max    8.461550e+07

# %%
meta.index#describe indexes range
# Out:
# RangeIndex(start=0, stop=252, step=1)

# %%
meta.iloc[1,3]#selection of data
# Out:
# 258.450012

# %%
meta.iloc[240:,:]#selct the rows
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 240 2024-05-13  472.750000  473.350006  462.850006  468.010010  468.010010
# 241 2024-05-14  463.369995  472.540009  460.079987  471.850006  471.850006
# 242 2024-05-15  474.980011  482.500000  471.200012  481.540009  481.540009
# 243 2024-05-16  475.000000  477.690002  472.750000  473.230011  473.230011
# 244 2024-05-17  470.829987  472.799988  468.420013  471.910004  471.910004
# 245 2024-05-20  469.950012  473.200012  467.040009  468.839996  468.839996
# 246 2024-05-21  467.119995  470.700012  462.269989  464.630005  464.630005
# 247 2024-05-22  467.869995  473.720001  465.649994  467.779999  467.779999
# 248 2024-05-23  472.880005  474.359985  461.540009  465.779999  465.779999
# 249 2024-05-24  467.619995  479.850006  466.299988  478.220001  478.220001
# 250 2024-05-28  476.579987  480.859985  474.839996  479.920013  479.920013
# ...

# %%
meta.columns#describe the columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
meta.loc[0:251 ,"Open"].plot()#display the open prices varying throughout an entire year
# Out:
# <AxesSubplot:>

# %%
# Visualizing varying of closing price of stocks 
meta.loc[0:49,"Close"].plot()#from 5/30/2023 to 7/18/2023
meta.loc[50:99,"Close"].plot()#from 8/10/2023 to 9/28/2023
meta.loc[100:149,"Close"].plot()#from 9/29/2023 to 1/3/2024
meta.loc[150:199,"Close"].plot()#from 1/4/2024 to 2/22/2024
meta.loc[200:251,"Close"].plot()#from 2/23/2024 to 4/13/2024
# Out:
# <AxesSubplot:>

# %%
meta["Close"]#to select/display and describe the column
# Out:
# 0      262.519989
# 1      264.720001
# 2      272.609985
# 3      272.609985
# 4      271.390015
#           ...
# 247    467.779999
# 248    465.779999
# 249    478.220001
# 250    479.920013
# 251    474.359985
# Name: Close, Length: 252, dtype: float64

# %%
meta["Price"]=meta["Close"].shift(-1)# add the new column price

# %%
meta.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-05-30  265.250000  268.649994  261.290009  262.519989  262.241760
# 1 2023-05-31  260.000000  265.000000  258.450012  264.720001  264.439423
# 2 2023-06-01  265.899994  274.000000  265.890015  272.609985  272.321045
# 3 2023-06-02  272.660004  275.350006  271.119995  272.609985  272.321045
# 4 2023-06-05  270.299988  275.570007  269.559998  271.390015  271.102356
#
#      Volume       Price
# 0  23816500  264.720001
# 1  25473700  272.609985
# 2  25609500  272.609985
# 3  19405300  271.390015
# 4  20742900  271.119995

# %%
#calculate the price difference by subtract the price of tommorow close price from price of today close price 
meta["Price DIFF"]=meta["Price"]-meta["Close"]

# %%
meta.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-05-30  265.250000  268.649994  261.290009  262.519989  262.241760
# 1 2023-05-31  260.000000  265.000000  258.450012  264.720001  264.439423
# 2 2023-06-01  265.899994  274.000000  265.890015  272.609985  272.321045
# 3 2023-06-02  272.660004  275.350006  271.119995  272.609985  272.321045
# 4 2023-06-05  270.299988  275.570007  269.559998  271.390015  271.102356
#
#      Volume       Price  Price DIFF
# 0  23816500  264.720001    2.200012
# 1  25473700  272.609985    7.889984
# 2  25609500  272.609985    0.000000
# 3  19405300  271.390015   -1.219970
# 4  20742900  271.119995   -0.270020

# %%
#calculate the daily return
meta["Return"]=meta["Price DIFF"]/meta["Close"]

# %%
meta.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-05-30  265.250000  268.649994  261.290009  262.519989  262.241760
# 1 2023-05-31  260.000000  265.000000  258.450012  264.720001  264.439423
# 2 2023-06-01  265.899994  274.000000  265.890015  272.609985  272.321045
# 3 2023-06-02  272.660004  275.350006  271.119995  272.609985  272.321045
# 4 2023-06-05  270.299988  275.570007  269.559998  271.390015  271.102356
#
#      Volume       Price  Price DIFF    Return
# 0  23816500  264.720001    2.200012  0.008380
# 1  25473700  272.609985    7.889984  0.029805
# 2  25609500  272.609985    0.000000  0.000000
# 3  19405300  271.390015   -1.219970 -0.004475
# 4  20742900  271.119995   -0.270020 -0.000995

# %%
#create the direction to Daily return

# %%
meta["Direction"]=[1 if meta.loc[ei,"Price DIFF"]>0 else -1 for ei in meta.index]

# %%
meta.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-05-30  265.250000  268.649994  261.290009  262.519989  262.241760
# 1 2023-05-31  260.000000  265.000000  258.450012  264.720001  264.439423
# 2 2023-06-01  265.899994  274.000000  265.890015  272.609985  272.321045
# 3 2023-06-02  272.660004  275.350006  271.119995  272.609985  272.321045
# 4 2023-06-05  270.299988  275.570007  269.559998  271.390015  271.102356
#
#      Volume       Price  Price DIFF    Return  Direction
# 0  23816500  264.720001    2.200012  0.008380          1
# 1  25473700  272.609985    7.889984  0.029805          1
# 2  25609500  272.609985    0.000000  0.000000         -1
# 3  19405300  271.390015   -1.219970 -0.004475         -1
# 4  20742900  271.119995   -0.270020 -0.000995         -1

# %%
#Average and moving average

# %%
meta["Average 3"]=(meta["Close"]+meta["Close"].shift(1)+meta["Close"].shift(2))/3
meta.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-05-30  265.250000  268.649994  261.290009  262.519989  262.241760
# 1 2023-05-31  260.000000  265.000000  258.450012  264.720001  264.439423
# 2 2023-06-01  265.899994  274.000000  265.890015  272.609985  272.321045
# 3 2023-06-02  272.660004  275.350006  271.119995  272.609985  272.321045
# 4 2023-06-05  270.299988  275.570007  269.559998  271.390015  271.102356
#
#      Volume       Price  Price DIFF    Return  Direction   Average 3
# 0  23816500  264.720001    2.200012  0.008380          1         NaN
# 1  25473700  272.609985    7.889984  0.029805          1         NaN
# 2  25609500  272.609985    0.000000  0.000000         -1  266.616658
# 3  19405300  271.390015   -1.219970 -0.004475         -1  269.979990
# 4  20742900  271.119995   -0.270020 -0.000995         -1  272.203328

# %%
meta["MA10"]=meta["Close"].rolling(10).mean()
meta["MA50"]=meta["Close"].rolling(50).mean()

# %%
meta["Close"].plot(legend=True)
meta["MA10"].plot(color="red",legend=True)
meta["MA50"].plot(legend=True)
# Out:
# <AxesSubplot:>

# %%
meta["shares"]=[1 if meta.loc[ei,"MA10"]>meta.loc[ei,"MA50"] else 0 for ei in meta.index]# evaluate shares 
# 1 indiacte the points where the MA10 crosses above the MA50 can be potential buy signals, 
# 0 indicate the MA10 crosses below the MA50, it can be potential sell signals.

# %%
meta.iloc[170:230,:]
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 170 2024-02-01  393.940002  400.500000  393.049988  394.779999  394.361572
# 171 2024-02-02  459.600006  485.959991  453.010010  474.989990  474.486542
# 172 2024-02-05  469.880005  471.899994  459.220001  459.410004  458.923065
# 173 2024-02-06  464.000000  467.119995  453.000000  454.720001  454.238037
# 174 2024-02-07  458.000000  471.519989  456.179993  469.589996  469.092285
# 175 2024-02-08  468.320007  470.589996  465.029999  470.000000  469.501862
# 176 2024-02-09  472.950012  473.589996  467.470001  468.109985  467.613831
# 177 2024-02-12  468.190002  479.149994  466.579987  468.899994  468.403015
# 178 2024-02-13  456.869995  467.890015  455.089996  460.119995  459.632324
# 179 2024-02-14  467.929993  474.109985  466.089996  473.279999  472.778381
# 180 2024-02-15  475.279999  488.619995  472.220001  484.029999  483.516968
# ...

# %%
meta["Profit"]=[meta.loc[ei,"Price"]-meta.loc[ei,"Close"]#calculate profit
                if meta.loc[ei,"shares"]==1 else 0 for ei in meta.index]
meta["Profit"].plot()
plt.axhline(y=0,color="red")
#below the 0 horizontal axis shows the loss of money in that periods

# %%
meta["Wealth"]=meta["Profit"].cumsum()# calculate wealth

# %%
meta["Wealth"].plot()
# Out:
# <AxesSubplot:>

# %%
print("Total money win is",meta.loc[meta.index[-1],"Wealth"])
print("Total money spent is",meta.loc[meta.index[0],"Close"])
# Out:
# Total money win is 105.26000900000003
# Total money spent is 262.519989

# %%
meta.tail()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 247 2024-05-22  467.869995  473.720001  465.649994  467.779999  467.779999
# 248 2024-05-23  472.880005  474.359985  461.540009  465.779999  465.779999
# 249 2024-05-24  467.619995  479.850006  466.299988  478.220001  478.220001
# 250 2024-05-28  476.579987  480.859985  474.839996  479.920013  479.920013
# 251 2024-05-29  474.660004  479.850006  473.700012  474.359985  474.359985
#
#        Volume       Price  Price DIFF    Return  Direction   Average 3  \
# 247  10078600  465.779999   -2.000000 -0.004276         -1  467.083333
# 248  11747900  478.220001   12.440002  0.026708          1  466.063334
# 249  12012300  479.920013    1.700012  0.003555          1  470.593333
# 250  10175800  474.359985   -5.560028 -0.011585         -1  474.640004
# 251   9208600         NaN         NaN       NaN         -1  477.500000
#
#            MA10        MA50  shares  Profit      Wealth
# ...

# %%
import numpy as np
from scipy.stats import norm

# %%
meta["LogReturn"] = np.log(meta["Close"].shift(-1)) - np.log(meta["Close"])# calculating log daily return

# %%
mu=meta["LogReturn"].mean()
sigma=meta["LogReturn"].std(ddof=1)

density=pd.DataFrame()
density["x"]=np.arange(meta["LogReturn"].min()-0.01,meta["LogReturn"].max()+0.01,0.001)
density["PDF"]=norm.pdf(density["x"],mu,sigma)

meta["LogReturn"].hist(bins=50,figsize=(15,8))
plt.plot(density["x"],density["PDF"],color="red")
plt.show()

#Plot the histrogram to show the distribution of long return of META stocks
#We can see it is very close to a norml distribution

# %%
meta.tail()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 247 2024-05-22  467.869995  473.720001  465.649994  467.779999  467.779999
# 248 2024-05-23  472.880005  474.359985  461.540009  465.779999  465.779999
# 249 2024-05-24  467.619995  479.850006  466.299988  478.220001  478.220001
# 250 2024-05-28  476.579987  480.859985  474.839996  479.920013  479.920013
# 251 2024-05-29  474.660004  479.850006  473.700012  474.359985  474.359985
#
#        Volume       Price  Price DIFF    Return  Direction   Average 3  \
# 247  10078600  465.779999   -2.000000 -0.004276         -1  467.083333
# 248  11747900  478.220001   12.440002  0.026708          1  466.063334
# 249  12012300  479.920013    1.700012  0.003555          1  470.593333
# 250  10175800  474.359985   -5.560028 -0.011585         -1  474.640004
# 251   9208600         NaN         NaN       NaN         -1  477.500000
#
#            MA10        MA50  shares  Profit      Wealth  LogReturn
# ...

# %%
#calculating the probability of stock price will drop over certain percentage in a day

# %%
#probability that the stock price of meta will drop over 5% in day
prob_return=norm.cdf(-0.05,mu,sigma)
print("The probability of stock price will drop over 5% in a day is",prob_return)
# Out:
# The probability of stock price will drop over 5% in a day is 0.009073234487686082

# %%
#calculating the probability of stock price will drop over certain percentage in a year

# %%
#drop over 40% in 220 days
mu220=220*mu
sigma220=(220**0.5)*sigma
print("The probability of dropping over 40% in 220 days is", norm.cdf(-0.4,mu220,sigma220))
# Out:
# The probability of dropping over 40% in 220 days is 0.002598315081310054

# %%
# calculating the Var(Value of Risk)

# %%
var=norm.ppf(0.05,mu,sigma)#ppf meaning is Percent-Point Function
print("Single day value at risk",var)
# Out:
# Single day value at risk -0.03409391488194108

# %%
# Quatile
# 5% quatile
print("5% quantile",norm.ppf(0.05,mu,sigma))#ppf meaning is Percent-Point Function 
# 95% quatile
print("95% quantile",norm.ppf(0.95,mu,sigma))
# Out:
# 5% quantile -0.03409391488194108
# 95% quantile 0.03880817199565492

# %%
# Estimate the average stock return with 90% Confidence Interval

# %%
sample_size = meta['LogReturn'].shape[0]
sample_mean =meta['LogReturn'].mean()
sample_std =meta['LogReturn'].std(ddof=1) / sample_size**0.5

# left and right quantile
z_left = norm.ppf(0.05)
z_right = norm.ppf(0.95)

# upper and lower bound
interval_left = sample_mean+z_left *sample_std
interval_right = sample_mean+z_right*sample_std

print("Sample mean is ",sample_mean)
print("90% confidence interval is")
print(interval_left,interval_right,)

#we can see the output is positive there fore average stock return is positive
# Out:
# Sample mean is  0.0023571285568569304
# 90% confidence interval is
# 6.0928652859974005e-05 0.004653328460853886
